# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# create random dataset
torch.manual_seed(42)
X = torch.linspace(0, 10, 100).reshape(-1, 1)
Y = X * 2.5 + 7.0 + torch.randn_like(X) * 2

# %%
# create model class
class LRModel(nn.Module):
    def __init__(self):
        super(LRModel, self).__init__()
        self.linear = nn.Linear(1, 1)
    def forward(self, x):
        return self.linear(x)

# %%
# define model andits hyperparamters
model = LRModel()
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# training set
epochs = 5000
losses = []
for epoch in range(epochs):
    y_pred = model(X)
    loss = criterion(y_pred, Y)
    losses.append(loss.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if (epoch % 50) == 0:
        print(f"epoch {epoch}, loss: {loss.item():.4f}")

plt.plot(losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.show()
# Out:
# epoch 0, loss: 438.8629
# epoch 50, loss: 12.6182
# epoch 100, loss: 9.1814
# epoch 150, loss: 7.0920
# epoch 200, loss: 5.8216
# epoch 250, loss: 5.0493
# epoch 300, loss: 4.5798
# epoch 350, loss: 4.2943
# epoch 400, loss: 4.1208
# epoch 450, loss: 4.0152
# epoch 500, loss: 3.9511
# epoch 550, loss: 3.9121
# epoch 600, loss: 3.8884
# epoch 650, loss: 3.8740
# epoch 700, loss: 3.8652
# epoch 750, loss: 3.8599
# epoch 800, loss: 3.8566
# epoch 850, loss: 3.8547
# epoch 900, loss: 3.8535
# epoch 950, loss: 3.8527
# epoch 1000, loss: 3.8523
# epoch 1050, loss: 3.8520
# epoch 1100, loss: 3.8519
# epoch 1150, loss: 3.8518
# epoch 1200, loss: 3.8517
# epoch 1250, loss: 3.8517
# epoch 1300, loss: 3.8516
# epoch 1350, loss: 3.8516
# epoch 1400, loss: 3.8516
# epoch 1450, loss: 3.8516
# epoch 1500, loss: 3.8516
# epoch 1550, loss: 3.8516
# epoch 1600, loss: 3.8516
# epoch 1650, loss: 3.8516
# epoch 1700, loss: 3.8516
# epoch 1750, loss: 3.8516
# epoch 1800, loss: 3.8516
# epoch 1850, loss: 3.8516
# epoch 1900, loss: 3.8516
# epoch 1950, loss: 3.8516
# epoch 2000, loss: 3.8516
# epoch 2050, loss: 3.8516
# epoch 2100, loss: 3.8516
# epoch 2150, loss: 3.8516
# epoch 2200, loss: 3.8516
# epoch 2250, loss: 3.8516
# epoch 2300, loss: 3.8516
# epoch 2350, loss: 3.8516
# epoch 2400, loss: 3.8516
# epoch 2450, loss: 3.8516
# epoch 2500, loss: 3.8516
# epoch 2550, loss: 3.8516
# epoch 2600, loss: 3.8516
# epoch 2650, loss: 3.8516
# epoch 2700, loss: 3.8516
# epoch 2750, loss: 3.8516
# epoch 2800, loss: 3.8516
# epoch 2850, loss: 3.8516
# epoch 2900, loss: 3.8516
# epoch 2950, loss: 3.8516
# epoch 3000, loss: 3.8516
# epoch 3050, loss: 3.8516
# epoch 3100, loss: 3.8516
# epoch 3150, loss: 3.8516
# epoch 3200, loss: 3.8516
# epoch 3250, loss: 3.8516
# epoch 3300, loss: 3.8516
# epoch 3350, loss: 3.8516
# epoch 3400, loss: 3.8516
# epoch 3450, loss: 3.8516
# epoch 3500, loss: 3.8516
# epoch 3550, loss: 3.8516
# epoch 3600, loss: 3.8516
# epoch 3650, loss: 3.8516
# epoch 3700, loss: 3.8516
# epoch 3750, loss: 3.8516
# epoch 3800, loss: 3.8516
# epoch 3850, loss: 3.8516
# epoch 3900, loss: 3.8516
# epoch 3950, loss: 3.8516
# epoch 4000, loss: 3.8516
# epoch 4050, loss: 3.8516
# epoch 4100, loss: 3.8516
# epoch 4150, loss: 3.8516
# epoch 4200, loss: 3.8516
# epoch 4250, loss: 3.8516
# epoch 4300, loss: 3.8516
# epoch 4350, loss: 3.8516
# epoch 4400, loss: 3.8516
# epoch 4450, loss: 3.8516
# epoch 4500, loss: 3.8516
# epoch 4550, loss: 3.8516
# epoch 4600, loss: 3.8516
# epoch 4650, loss: 3.8516
# epoch 4700, loss: 3.8516
# epoch 4750, loss: 3.8516
# epoch 4800, loss: 3.8516
# epoch 4850, loss: 3.8516
# epoch 4900, loss: 3.8516
# epoch 4950, loss: 3.8516

# %%
# visualize the model and its dataset
preds = model(X).detach()
plt.scatter(X, Y, label="Original Data")
plt.plot(X, preds, color="red", label="Fitted Line")
plt.legend()
plt.title("Linear Regression Model Predictions")
plt.show()
